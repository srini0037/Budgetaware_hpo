# %%
import warnings
warnings.filterwarnings("ignore")

import optuna
import pandas as pd
from sklearn.datasets import load_breast_cancer, fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %%
optuna.__version__
# Out:
# '4.6.0'

# %%
def load_dataset(name: str):
    """
    Returns X, y for a given dataset name.
    Supported:
      - 'breast_cancer'
      - 'adult'
      - 'credit-g'
    """
    if name == "breast_cancer":
        data = load_breast_cancer(as_frame=True)
        X = data.data
        y = data.target
        return X, y
    
    elif name == "adult":
        adult = fetch_openml("adult", version=2, as_frame=True)
        X = adult.data
        y = adult.target
        return X, y
    
    elif name == "credit-g":
        credit = fetch_openml("credit-g", version=1, as_frame=True)
        X = credit.data
        y = credit.target
        return X, y
    
    else:
        raise ValueError(f"Unknown dataset name: {name}")

# %%
def build_preprocessor(X):
    categorical = X.select_dtypes(include=["object", "category"]).columns
    numeric = X.select_dtypes(include=["int64", "float64", "int32", "float32"]).columns

    preprocess = ColumnTransformer([
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical)
    ])

    return preprocess

# %%
def run_lr_baseline(X, y, random_state=42):
    """
    Train/test split + baseline Logistic Regression.
    Returns baseline_f1 (macro).
    """
    preprocess = build_preprocessor(X)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=0.2,
        random_state=random_state,
        stratify=y
    )

    model = Pipeline([
        ("pre", preprocess),
        ("clf", LogisticRegression(max_iter=200))
    ])

    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    f1 = f1_score(y_test, preds, average="macro")
    return f1, preprocess, X_train, X_test, y_train, y_test


def run_lr_hpo(preprocess, X_train, X_test, y_train, y_test, n_trials=30, random_state=42):
    """
    HPO on Logistic Regression using Optuna.
    Uses same train/test split and same preprocessor.
    Returns best_f1, best_params, study.
    """
    def objective(trial):
        C = trial.suggest_float("C", 1e-4, 10.0, log=True)
        class_weight = trial.suggest_categorical("class_weight", [None, "balanced"])

        model = Pipeline([
            ("pre", preprocess),
            ("clf", LogisticRegression(
                max_iter=300,
                C=C,
                penalty="l2",
                class_weight=class_weight
            ))
        ])

        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        return f1_score(y_test, preds, average="macro")

    sampler = optuna.samplers.TPESampler(seed=random_state)
    study = optuna.create_study(direction="maximize", sampler=sampler)
    study.optimize(objective, n_trials=n_trials, show_progress_bar=False)

    best_f1 = study.best_value
    best_params = study.best_params

    return best_f1, best_params, study

# %%
dataset_names = ["breast_cancer", "adult", "credit-g"]

all_results = []

for name in dataset_names:
    print(f"\n=== DATASET: {name} ===")
    
    # 1. Load data
    X, y = load_dataset(name)
    
    # 2. Baseline LR
    baseline_f1, preprocess, X_train, X_test, y_train, y_test = run_lr_baseline(X, y)
    print(f"Baseline LR F1_macro: {baseline_f1:.4f}")
    
    # 3. HPO LR
    hpo_f1, best_params, study = run_lr_hpo(
        preprocess, X_train, X_test, y_train, y_test,
        n_trials=30
    )
    print(f"HPO LR F1_macro: {hpo_f1:.4f}")
    print(f"Improvement: {hpo_f1 - baseline_f1:.4f}")
    print(f"Best params: {best_params}")
    
    # 4. Store
    all_results.append({
        "dataset": name,
        "model": "logistic_regression",
        "baseline_f1_macro": baseline_f1,
        "hpo_f1_macro": hpo_f1,
        "improvement": hpo_f1 - baseline_f1,
        "best_params": best_params
    })

results_df = pd.DataFrame(all_results)
results_df
# Out:
# === DATASET: breast_cancer ===
# [I 2025-12-02 01:06:22,075] A new study created in memory with name: no-name-d23a1f30-382a-41c4-bc50-ca2be9900db6
# [I 2025-12-02 01:06:22,099] Trial 0 finished with value: 0.9422297297297297 and parameters: {'C': 0.0074593432857265485, 'class_weight': None}. Best is trial 0 with value: 0.9422297297297297.
# [I 2025-12-02 01:06:22,109] Trial 1 finished with value: 0.9715828832571666 and parameters: {'C': 0.09846738873614563, 'class_weight': None}. Best is trial 1 with value: 0.9715828832571666.
# [I 2025-12-02 01:06:22,118] Trial 2 finished with value: 0.5832502492522433 and parameters: {'C': 0.00019517224641449495, 'class_weight': None}. Best is trial 1 with value: 0.9715828832571666.
# [I 2025-12-02 01:06:22,129] Trial 3 finished with value: 0.9535338713621913 and parameters: {'C': 0.3470266988650412, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9715828832571666.
# [I 2025-12-02 01:06:22,143] Trial 4 finished with value: 0.9811507936507937 and parameters: {'C': 1.452824663751602, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,152] Trial 5 finished with value: 0.9329805996472662 and parameters: {'C': 0.0008260808399079611, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,166] Trial 6 finished with value: 0.9718634306869601 and parameters: {'C': 0.01444525102276306, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,175] Trial 7 finished with value: 0.9329805996472662 and parameters: {'C': 0.0004982752357076451, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,184] Trial 8 finished with value: 0.9521289997480473 and parameters: {'C': 0.019069966103000432, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,196] Trial 9 finished with value: 0.9521289997480473 and parameters: {'C': 0.03725393839578886, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,216] Trial 10 finished with value: 0.9811507936507937 and parameters: {'C': 7.762120319752449, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,230] Trial 11 finished with value: 0.9811507936507937 and parameters: {'C': 7.041830285015986, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,246] Trial 12 finished with value: 0.9718634306869601 and parameters: {'C': 8.19260227903101, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,255] Trial 13 finished with value: 0.9811507936507937 and parameters: {'C': 1.247117403453705, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# Baseline LR F1_macro: 0.9812
# [I 2025-12-02 01:06:22,270] Trial 14 finished with value: 0.9811507936507937 and parameters: {'C': 1.0162435907226077, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,284] Trial 15 finished with value: 0.9811507936507937 and parameters: {'C': 1.970755824338177, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,296] Trial 16 finished with value: 0.9811507936507937 and parameters: {'C': 0.22894626561527406, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,308] Trial 17 finished with value: 0.9811507936507937 and parameters: {'C': 2.8672039737492496, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,318] Trial 18 finished with value: 0.9535338713621913 and parameters: {'C': 0.28148296482457225, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,332] Trial 19 finished with value: 0.951575906889814 and parameters: {'C': 0.0044018420913327395, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,344] Trial 20 finished with value: 0.9811507936507937 and parameters: {'C': 0.6414457214254623, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,358] Trial 21 finished with value: 0.9623015873015872 and parameters: {'C': 9.725155322086662, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,370] Trial 22 finished with value: 0.9811507936507937 and parameters: {'C': 3.70594929574341, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,383] Trial 23 finished with value: 0.9811507936507937 and parameters: {'C': 5.234486498053107, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,395] Trial 24 finished with value: 0.9811507936507937 and parameters: {'C': 1.9503914268343598, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,407] Trial 25 finished with value: 0.9623015873015872 and parameters: {'C': 9.92686677050091, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,417] Trial 26 finished with value: 0.9626596790042581 and parameters: {'C': 0.08995783454643097, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,429] Trial 27 finished with value: 0.9811507936507937 and parameters: {'C': 0.8291355807626201, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,441] Trial 28 finished with value: 0.9811507936507937 and parameters: {'C': 3.336694308580925, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# [I 2025-12-02 01:06:22,452] Trial 29 finished with value: 0.9811507936507937 and parameters: {'C': 0.45322427145453603, 'class_weight': None}. Best is trial 4 with value: 0.9811507936507937.
# HPO LR F1_macro: 0.9812
# Improvement: 0.0000
# Best params: {'C': 1.452824663751602, 'class_weight': None}
#
# === DATASET: adult ===
# [I 2025-12-02 01:06:22,965] A new study created in memory with name: no-name-cb051469-69ca-4c7e-8925-fc6a3a63e3c3
# [I 2025-12-02 01:06:23,160] Trial 0 finished with value: 0.7763003658151166 and parameters: {'C': 0.0074593432857265485, 'class_weight': None}. Best is trial 0 with value: 0.7763003658151166.
# Baseline LR F1_macro: 0.7851
# [I 2025-12-02 01:06:23,435] Trial 1 finished with value: 0.7838620206108089 and parameters: {'C': 0.09846738873614563, 'class_weight': None}. Best is trial 1 with value: 0.7838620206108089.
# [I 2025-12-02 01:06:23,600] Trial 2 finished with value: 0.640235246472991 and parameters: {'C': 0.00019517224641449495, 'class_weight': None}. Best is trial 1 with value: 0.7838620206108089.
# [I 2025-12-02 01:06:23,856] Trial 3 finished with value: 0.7712696774574349 and parameters: {'C': 0.3470266988650412, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.7838620206108089.
# [I 2025-12-02 01:06:24,153] Trial 4 finished with value: 0.7849459892116938 and parameters: {'C': 1.452824663751602, 'class_weight': None}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:24,345] Trial 5 finished with value: 0.7621317143932771 and parameters: {'C': 0.0008260808399079611, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:24,570] Trial 6 finished with value: 0.7701099621490728 and parameters: {'C': 0.01444525102276306, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:24,753] Trial 7 finished with value: 0.7598607829346631 and parameters: {'C': 0.0004982752357076451, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:24,982] Trial 8 finished with value: 0.7801800243119328 and parameters: {'C': 0.019069966103000432, 'class_weight': None}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:25,226] Trial 9 finished with value: 0.7809463622423791 and parameters: {'C': 0.03725393839578886, 'class_weight': None}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:25,512] Trial 10 finished with value: 0.783965774421661 and parameters: {'C': 7.762120319752449, 'class_weight': None}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:25,778] Trial 11 finished with value: 0.7845298634373779 and parameters: {'C': 7.041830285015986, 'class_weight': None}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:26,054] Trial 12 finished with value: 0.7845298634373779 and parameters: {'C': 8.19260227903101, 'class_weight': None}. Best is trial 4 with value: 0.7849459892116938.
# [I 2025-12-02 01:06:26,336] Trial 13 finished with value: 0.7849863928321286 and parameters: {'C': 1.247117403453705, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:26,591] Trial 14 finished with value: 0.7838571080975272 and parameters: {'C': 0.8282245617333772, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:26,858] Trial 15 finished with value: 0.7846102498928492 and parameters: {'C': 1.0833638781816703, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:27,135] Trial 16 finished with value: 0.7847580631507465 and parameters: {'C': 1.6423980586019935, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:27,371] Trial 17 finished with value: 0.784159617393402 and parameters: {'C': 0.19312939038749688, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:27,642] Trial 18 finished with value: 0.7717599889741392 and parameters: {'C': 2.116831119240102, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:27,901] Trial 19 finished with value: 0.784164947000983 and parameters: {'C': 0.07707352705691688, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:28,162] Trial 20 finished with value: 0.7841197181790833 and parameters: {'C': 0.42323088514645146, 'class_weight': None}. Best is trial 13 with value: 0.7849863928321286.
# [I 2025-12-02 01:06:28,430] Trial 21 finished with value: 0.7852148527001674 and parameters: {'C': 1.6215046406203981, 'class_weight': None}. Best is trial 21 with value: 0.7852148527001674.
# [I 2025-12-02 01:06:28,685] Trial 22 finished with value: 0.7840056470855309 and parameters: {'C': 2.8646941459848536, 'class_weight': None}. Best is trial 21 with value: 0.7852148527001674.
# [I 2025-12-02 01:06:28,934] Trial 23 finished with value: 0.7843479579535769 and parameters: {'C': 0.7238489000691398, 'class_weight': None}. Best is trial 21 with value: 0.7852148527001674.
# [I 2025-12-02 01:06:29,196] Trial 24 finished with value: 0.7853951480194554 and parameters: {'C': 3.036799422352348, 'class_weight': None}. Best is trial 24 with value: 0.7853951480194554.
# [I 2025-12-02 01:06:29,471] Trial 25 finished with value: 0.7848318538179843 and parameters: {'C': 3.649116862426294, 'class_weight': None}. Best is trial 24 with value: 0.7853951480194554.
# [I 2025-12-02 01:06:29,720] Trial 26 finished with value: 0.7709615936272562 and parameters: {'C': 0.19651104028030178, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.7853951480194554.
# [I 2025-12-02 01:06:29,895] Trial 27 finished with value: 0.7695683458932367 and parameters: {'C': 0.0036406143753283933, 'class_weight': None}. Best is trial 24 with value: 0.7853951480194554.
# [I 2025-12-02 01:06:30,163] Trial 28 finished with value: 0.7845298634373779 and parameters: {'C': 4.031460965860914, 'class_weight': None}. Best is trial 24 with value: 0.7853951480194554.
# [I 2025-12-02 01:06:30,419] Trial 29 finished with value: 0.783708257431204 and parameters: {'C': 0.4543545325044071, 'class_weight': None}. Best is trial 24 with value: 0.7853951480194554.
# HPO LR F1_macro: 0.7854
# Improvement: 0.0003
# Best params: {'C': 3.036799422352348, 'class_weight': None}
#
# === DATASET: credit-g ===
# [I 2025-12-02 01:06:32,640] A new study created in memory with name: no-name-00f8b6d7-069f-4cd0-bf41-5363a212db32
# [I 2025-12-02 01:06:32,660] Trial 0 finished with value: 0.5069696562233875 and parameters: {'C': 0.0074593432857265485, 'class_weight': None}. Best is trial 0 with value: 0.5069696562233875.
# [I 2025-12-02 01:06:32,683] Trial 1 finished with value: 0.6945041927740889 and parameters: {'C': 0.09846738873614563, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,701] Trial 2 finished with value: 0.4117647058823529 and parameters: {'C': 0.00019517224641449495, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,723] Trial 3 finished with value: 0.6567996567996568 and parameters: {'C': 0.3470266988650412, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,751] Trial 4 finished with value: 0.6442154336891179 and parameters: {'C': 1.452824663751602, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,769] Trial 5 finished with value: 0.6592292089249493 and parameters: {'C': 0.0008260808399079611, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,787] Trial 6 finished with value: 0.6648847043804356 and parameters: {'C': 0.01444525102276306, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,808] Trial 7 finished with value: 0.6656239887822242 and parameters: {'C': 0.0004982752357076451, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.6945041927740889.
# Baseline LR F1_macro: 0.6362
# [I 2025-12-02 01:06:32,828] Trial 8 finished with value: 0.5667211432480712 and parameters: {'C': 0.019069966103000432, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,848] Trial 9 finished with value: 0.6836158192090396 and parameters: {'C': 0.03725393839578886, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,870] Trial 10 finished with value: 0.6442154336891179 and parameters: {'C': 5.86072399830607, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,895] Trial 11 finished with value: 0.6484844747309673 and parameters: {'C': 0.30240503427727145, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,919] Trial 12 finished with value: 0.6945041927740889 and parameters: {'C': 0.10428462672011099, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,940] Trial 13 finished with value: 0.6775793650793651 and parameters: {'C': 0.12634630534658148, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,963] Trial 14 finished with value: 0.4293727936553992 and parameters: {'C': 0.0047203682560124196, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:32,983] Trial 15 finished with value: 0.6784261798921782 and parameters: {'C': 0.07077084911655575, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,008] Trial 16 finished with value: 0.6361505966513521 and parameters: {'C': 0.9802989335981928, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,029] Trial 17 finished with value: 0.4117647058823529 and parameters: {'C': 0.0020481270530581766, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,056] Trial 18 finished with value: 0.6375929682217715 and parameters: {'C': 7.198073372673799, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,081] Trial 19 finished with value: 0.6608183528105824 and parameters: {'C': 0.16128481352749796, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,107] Trial 20 finished with value: 0.6361505966513521 and parameters: {'C': 1.1619253086916674, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,127] Trial 21 finished with value: 0.6836158192090396 and parameters: {'C': 0.039759261932535525, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,148] Trial 22 finished with value: 0.6836158192090396 and parameters: {'C': 0.037862668099913205, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,169] Trial 23 finished with value: 0.6820349761526232 and parameters: {'C': 0.11355324199678986, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,196] Trial 24 finished with value: 0.6484844747309673 and parameters: {'C': 0.5125887011495807, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,217] Trial 25 finished with value: 0.49192524042823443 and parameters: {'C': 0.0068479764642342105, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,238] Trial 26 finished with value: 0.6737880691997112 and parameters: {'C': 0.06007700641118078, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,260] Trial 27 finished with value: 0.5592903828197946 and parameters: {'C': 0.021157425331900924, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,285] Trial 28 finished with value: 0.6442154336891179 and parameters: {'C': 2.7030009968463258, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# [I 2025-12-02 01:06:33,306] Trial 29 finished with value: 0.5426829268292683 and parameters: {'C': 0.010759541817711583, 'class_weight': None}. Best is trial 1 with value: 0.6945041927740889.
# HPO LR F1_macro: 0.6945
# Improvement: 0.0584
# Best params: {'C': 0.09846738873614563, 'class_weight': None}
#          dataset                model  baseline_f1_macro  hpo_f1_macro  \
# 0  breast_cancer  logistic_regression           0.981151      0.981151
# 1          adult  logistic_regression           0.785060      0.785395
# 2       credit-g  logistic_regression           0.636151      0.694504
#
#    improvement                                       best_params
# 0     0.000000    {'C': 1.452824663751602, 'class_weight': None}
# 1     0.000335    {'C': 3.036799422352348, 'class_weight': None}
# 2     0.058354  {'C': 0.09846738873614563, 'class_weight': None}

# %%
import os

os.makedirs("../results", exist_ok=True)

results_path = "../results/lr_optionB_multi_datasets.csv"
results_df.to_csv(results_path, index=False)
results_path
# Out:
# '../results/lr_optionB_multi_datasets.csv'
